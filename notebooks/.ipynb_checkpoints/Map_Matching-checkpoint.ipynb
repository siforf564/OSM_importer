# %%
import networkx as nx
import osmnx as ox
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
import geopandas as gpd
import pandas as pd
import numpy as np
import gtfs_kit as gk
import matplotlib.pyplot as plt

from shapely import geometry


# %matplotlib inline
ox.config(log_console=True)
ox.__version__

data_dir = '../data/'

# %%
feed=gk.read_feed('data/stm.zip',dist_units='km')

# %%
trip = feed.stop_times[feed.stop_times['trip_id']=='205408909']

# %%
trip=trip.merge(feed.stops[['stop_id','stop_lat','stop_lon']],left_on='stop_id',right_on='stop_id')

# %%
meili_df = trip[['departure_time','stop_lat','stop_lon']].rename(columns={'departure_time':'time','stop_lat':'lat','stop_lon':'lon'})

# %%
meili_df
# Out:
#         time        lat        lon
# 0   05:13:00  45.530024 -73.623756
# 1   05:14:51  45.529510 -73.622634
# 2   05:16:12  45.532296 -73.620360
# 3   05:17:00  45.533908 -73.618877
# 4   05:17:15  45.535046 -73.617454
# 5   05:17:42  45.537393 -73.615162
# 6   05:18:00  45.538922 -73.613838
# 7   05:18:48  45.540498 -73.613116
# 8   05:19:48  45.542320 -73.612026
# 9   05:20:39  45.543771 -73.610716
# 10  05:21:30  45.545235 -73.609413
# 11  05:22:19  45.546606 -73.608136
# 12  05:23:00  45.547776 -73.607085
# 13  05:23:28  45.548962 -73.606010
# 14  05:23:55  45.550115 -73.604994
# 15  05:24:32  45.551701 -73.603602
# 16  05:25:00  45.552890 -73.602551
# 17  05:25:13  45.553481 -73.602022
# 18  05:25:40  45.554720 -73.600931
# 19  05:26:23  45.556635 -73.599297
# 20  05:27:03  45.558643 -73.598391
# 21  05:27:37  45.560137 -73.597055
# 22  05:28:12  45.561721 -73.595633
# 23  05:28:36  45.562778 -73.594688
# 24  05:29:10  45.564309 -73.593322
# 25  05:29:30  45.565177 -73.593251
# 26  05:30:00  45.565996 -73.595105
# 27  05:32:00  45.567450 -73.593988

# %%
meili_coordinates = meili_df.to_json(orient='records')

# %%
# Providing needed data for the body of Meili's request
meili_head = '{"shape":'
# Those are parameters that you can change according to the Meili's documentation
#meili_tail = ""","costing":"auto","shape_match":"walk_or_snap","filters":{"attributes":["edge.names","edge.id","matched.point","matched.type","matched.edge_index","matched.begin_route_discontinuity","matched.end_route_discontinuity"],"action":"include"}} """
meili_tail = ""","costing":"auto","shape_match":"walk_or_snap","filters":{"attributes":["edge.names","edge.way_id","matched.point","matched.type","matched.edge_index"],"action":"include"}} """

# Combining all the string into a single request
meili_request_body = meili_head + meili_coordinates + meili_tail

# %%
meili_request_body
# Out:
# '{"shape":[{"time":"05:13:00","lat":45.530024,"lon":-73.623756},{"time":"05:14:51","lat":45.52951,"lon":-73.622634},{"time":"05:16:12","lat":45.532296,"lon":-73.62036},{"time":"05:17:00","lat":45.533908,"lon":-73.618877},{"time":"05:17:15","lat":45.535046,"lon":-73.617454},{"time":"05:17:42","lat":45.537393,"lon":-73.615162},{"time":"05:18:00","lat":45.538922,"lon":-73.613838},{"time":"05:18:48","lat":45.540498,"lon":-73.613116},{"time":"05:19:48","lat":45.54232,"lon":-73.612026},{"time":"05:20:39","lat":45.543771,"lon":-73.610716},{"time":"05:21:30","lat":45.545235,"lon":-73.609413},{"time":"05:22:19","lat":45.546606,"lon":-73.608136},{"time":"05:23:00","lat":45.547776,"lon":-73.607085},{"time":"05:23:28","lat":45.548962,"lon":-73.60601},{"time":"05:23:55","lat":45.550115,"lon":-73.604994},{"time":"05:24:32","lat":45.551701,"lon":-73.603602},{"time":"05:25:00","lat":45.55289,"lon":-73.602551},{"time":"05:25:13","lat":45.553481,"lon":-73.602022},{"time":"05:25:40","lat":45.55472,"lon":-73.600931},{"time":"05:26:23","lat":45.556635,"lon":-73.599297},{"time":"05:27:03","lat":45.558643,"lon":-73.598391},{"time":"05:27:37","lat":45.560137,"lon":-73.597055},{"time":"05:28:12","lat":45.561721,"lon":-73.595633},{"time":"05:28:36","lat":45.562778,"lon":-73.594688},{"time":"05:29:10","lat":45.564309,"lon":-73.593322},{"time":"05:29:30","lat":45.565177,"lon":-73.593251},{"time":"05:30:00","lat":45.565996,"lon":-73.595105},{"time":"05:32:00","lat":45.56745,"lon":-73.593988}],"costing":"auto","shape_match":"walk_or_snap","filters":{"attributes":["edge.names","edge.way_id","matched.point","matched.type","matched.edge_index"],"action":"include"}} '

# %%
# The URL of our local Valhalla server
# "trace_route" means that we're sening a request to Meili
url = "http://localhost:8002/trace_attributes"

# Providing headers to the request
headers = {'Content-type': 'application/json'}

# We need to send our JSON as a string
data = str(meili_request_body)

# Sending a request
r = requests.post(url, data=data, headers=headers)

# %%
r
# Out:
# <Response [400]>

# %%
import json
# Checking if the response from Meili was correct
if r.status_code == 200:
    # Parsing the JSON response
    response_text = json.loads(r.text)
    
    # There are a lot more information that we got from Meili
    # but I'm interested in just 'tracepoints'
    resp = str(response_text['matched_points'])
    
    # This is a replacement to distinguish single None's in a row
    # from "waypoint_index" being None
    #resp = resp.replace("'waypoint_index': None", "'waypoint_index': '#'")
    #resp = resp.replace("None", "{'matchings_index': '#', 'name': '', 'waypoint_index': '#', 'alternatives_count': 0, 'distance': 0, 'location': [0.0, 0.0]}")
    
    # This is to make it a valid JSON
    resp = resp.replace("'", '"')
    resp = json.dumps(resp)
    resp = json.loads(resp)
    
    # Reading our JSON to a Pandas DataFrame
    df_response = pd.read_json(resp)
    df_response.rename(columns={'lat':'matched_lat','lon':'matched_lon'},inplace=True)
    
    
    # Merging our initial data with the response from Meili by index
    df_trip_optimized = pd.merge(meili_df, df_response, left_index=True, right_index=True)

# %%
df_trip_optimized
df_response
# Out:
#     edge_index     type  matched_lat  matched_lon
# 0            0  matched    45.529971   -73.623787
# 1            3  matched    45.529638   -73.622700
# 2            0  matched    45.532342   -73.620461
# 3            0  matched    45.533954   -73.618978
# 4            0  matched    45.535118   -73.617532
# 5            0  matched    45.537433   -73.615248
# 6            0  matched    45.538935   -73.613878
# 7            0  matched    45.540516   -73.613191
# 8            0  matched    45.542364   -73.612132
# 9            0  matched    45.543819   -73.610823
# 10           0  matched    45.545281   -73.609518
# 11           0  matched    45.546645   -73.608215
# 12           0  matched    45.547811   -73.607168
# 13           0  matched    45.549006   -73.606107
# 14           0  matched    45.550155   -73.605088
# 15           0  matched    45.551746   -73.603709
# 16           0  matched    45.552935   -73.602658
# 17           0  matched    45.553529   -73.602132
# 18           0  matched    45.554767   -73.601038
# 19           0  matched    45.556677   -73.599431
# 20           0  matched    45.558688   -73.598488
# 21           0  matched    45.560179   -73.597150
# 22           0  matched    45.561762   -73.595723
# 23           0  matched    45.562817   -73.594776
# 24           0  matched    45.564344   -73.593403
# 25           0  matched    45.565162   -73.593265
# 26           0  matched    45.565986   -73.595114
# 27          99  matched    45.567485   -73.594069

# %%
# define a point
location_point = tuple(df_trip_optimized[['lat','lon']].iloc[10])

# create network from point, inside bounding box of N, S, E, W each 750m from point
G = ox.graph_from_point(location_point, dist=2500,
                        dist_type='bbox', network_type='drive')

# %%
fig, ax = ox.plot_graph(G,node_size=0, show=False, close=False)
ax.scatter(df_trip_optimized['lon'],df_trip_optimized['lat'],c='r')
ax.scatter(df_trip_optimized['matched_lon'],df_trip_optimized['matched_lat'],c='g')
plt.show()

# %%
response_text
# Out:
# {'matched_points': [{'edge_index': 0,
#    'type': 'matched',
#    'lat': 45.529971,
#    'lon': -73.623787},
#   {'edge_index': 3, 'type': 'matched', 'lat': 45.529638, 'lon': -73.6227},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.532342, 'lon': -73.620461},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.533954, 'lon': -73.618978},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.535118, 'lon': -73.617532},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.537433, 'lon': -73.615248},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.538935, 'lon': -73.613878},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.540516, 'lon': -73.613191},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.542364, 'lon': -73.612132},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.543819, 'lon': -73.610823},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.545281, 'lon': -73.609518},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.546645, 'lon': -73.608215},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.547811, 'lon': -73.607168},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.549006, 'lon': -73.606107},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.550155, 'lon': -73.605088},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.551746, 'lon': -73.603709},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.552935, 'lon': -73.602658},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.553529, 'lon': -73.602132},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.554767, 'lon': -73.601038},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.556677, 'lon': -73.599431},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.558688, 'lon': -73.598488},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.560179, 'lon': -73.59715},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.561762, 'lon': -73.595723},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.562817, 'lon': -73.594776},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.564344, 'lon': -73.593403},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.565162, 'lon': -73.593265},
#   {'edge_index': 0, 'type': 'matched', 'lat': 45.565986, 'lon': -73.595114},
#   {'edge_index': 99, 'type': 'matched', 'lat': 45.567485, 'lon': -73.594069}],
#  'edges': [{'names': ['Rue Hutchison'], 'way_id': 165096613},
#   {'names': ['Rue Hutchison'], 'way_id': 165096613},
#   {'names': ['Rue Hutchison'], 'way_id': 165096613},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 184778964},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 184778963},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 692788659},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 692788659},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 184778977},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 184778977},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 184778974},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 463472298},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 463472298},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 463472299},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 463472300},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 330720152},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 330720153},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 330720153},
#   {'names': ['Rue Jean-Talon Ouest'], 'way_id': 164976439},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452402661},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 456308964},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427608},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427607},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427607},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 334772516},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 334772516},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427611},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427611},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427610},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463427610},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452083265},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452083265},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859256},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 766091389},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 766091389},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452645963},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398914},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398912},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452083266},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 766091392},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 462771099},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452641476},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 462771098},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 354348777},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452641477},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452641477},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398915},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398916},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398918},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398917},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 463398919},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859257},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859257},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859257},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859257},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859257},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464696731},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464696731},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 341094445},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 341094445},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464696732},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464696732},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121418},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121418},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121421},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121422},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121420},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121420},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 464121420},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859258},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859258},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859258},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859258},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754478},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754479},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754480},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754480},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754480},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754481},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754482},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754483},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460754483},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 455264718},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 455264717},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 452044778},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751541},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751542},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751543},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751544},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751545},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751546},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751341},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 460751342},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859259},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859259},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859259},
#   {'names': ['Rue Jean-Talon Est'], 'way_id': 37859259},
#   {'names': ['20e Avenue'], 'way_id': 20441264},
#   {'names': ['Rue Everett'], 'way_id': 47344820},
#   {'names': ['Rue Everett'], 'way_id': 47344820},
#   {'names': ['Rue Everett'], 'way_id': 47344820}],
#  'alternate_paths': []}

# %%
resp_edges = str(response_text['edges'])
resp_edges = resp_edges.replace("'", '"')
resp_edges = json.dumps(resp_edges)
resp_edges = json.loads(resp_edges)
    
    # Reading our JSON to a Pandas DataFrame
df_edges = pd.read_json(resp_edges)

# %%
df_edges
# Out:
#                      names     way_id
# 0          [Rue Hutchison]  165096613
# 1          [Rue Hutchison]  165096613
# 2          [Rue Hutchison]  165096613
# 3   [Rue Jean-Talon Ouest]  184778964
# 4   [Rue Jean-Talon Ouest]  184778963
# ..                     ...        ...
# 95    [Rue Jean-Talon Est]   37859259
# 96            [20e Avenue]   20441264
# 97           [Rue Everett]   47344820
# 98           [Rue Everett]   47344820
# 99           [Rue Everett]   47344820
#
# [100 rows x 2 columns]

# %%
df_edges.iloc[99]
# Out:
# names     [Rue Everett]
# way_id         47344820
# Name: 99, dtype: object

# %%
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)
gdf_nodes.head()
# Out:
#                   y          x          highway  street_count  ref  \
# osmid
# 26232411  45.524984 -73.582009  traffic_signals             3  NaN
# 26232412  45.524531 -73.582404  traffic_signals             4  NaN
# 26232413  45.523974 -73.582902  traffic_signals             4  NaN
# 26232418  45.522917 -73.583830              NaN             4  NaN
# 29287991  45.533508 -73.615736              NaN             3  NaN
#
#                             geometry
# osmid
# 26232411  POINT (-73.58201 45.52498)
# 26232412  POINT (-73.58240 45.52453)
# 26232413  POINT (-73.58290 45.52397)
# 26232418  POINT (-73.58383 45.52292)
# 29287991  POINT (-73.61574 45.53351)

# %%
gdf_edges.plot()
# Out:
# <AxesSubplot:>

# %%
gdf_edges[gdf_edges['osmid']=='165096613']
#gdf_edges
# Out:
# Empty GeoDataFrame
# Columns: [osmid, lanes, name, highway, oneway, length, maxspeed, geometry, ref, junction, access, bridge, tunnel]
# Index: []

# %%
for index in gdf_edges.index:
# Out:
# True

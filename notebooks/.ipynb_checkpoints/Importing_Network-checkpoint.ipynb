# %%
import osmnx as ox
import geopandas as gpd

from shapely import geometry

# %%
zones = gpd.read_file(r'../data/hull.geojson')
hull = zones['geometry'].values[0].buffer(1e-3).simplify(10)
hull

# %% [markdown]
# # osmnx filter

# %%
ox.graph_from_polygon(geometry.Polygon(hull), network_type='drive')
# Out:
# ---------------------------------------------------------------------------
# CRSError                                  Traceback (most recent call last)
# <ipython-input-10-b88746c938de> in <module>
# ----> 1 ox.graph_from_polygon(geometry.Polygon(hull), network_type='drive')
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/graph.py in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     412         # create a new buffered polygon 0.5km around the desired one
#     413         buffer_dist = 500
# --> 414         poly_proj, crs_utm = projection.project_geometry(polygon)
#     415         poly_proj_buff = poly_proj.buffer(buffer_dist)
#     416         poly_buff, _ = projection.project_geometry(poly_proj_buff, crs=crs_utm, to_latlong=True)
#
# ~/anaconda3/envs/ox/lib/python3.9/site-packages/osmnx/projection.py in project_geometry(geometry, crs, to_crs, to_latlong)
#      40
# ...

# %%
geometry.Polygon(hull)

# %% [markdown]
# # osmnx API

# %%
import time

a = time.time()
custom = ox.graph_from_polygon(hull, custom_filter=custom_filter)
b = time.time()
print(b-a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-94b24a15a1a6> in <module>
#       2
#       3 a = time.time()
# ----> 4 custom = ox.graph_from_polygon(hull, custom_filter=custom_filter)
#       5 b = time.time()
#       6 print(b-a)
#
# NameError: name 'custom_filter' is not defined
